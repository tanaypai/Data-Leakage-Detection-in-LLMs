# %%
# !pip install datasets transformers torch
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: datasets in ./.local/lib/python3.11/site-packages (3.0.2)
# Requirement already satisfied: transformers in ./.local/lib/python3.11/site-packages (4.46.1)
# Requirement already satisfied: torch in ./.local/lib/python3.11/site-packages (2.5.1)
# Requirement already satisfied: filelock in ./.local/lib/python3.11/site-packages (from datasets) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from datasets) (1.26.0)
# Requirement already satisfied: pyarrow>=15.0.0 in ./.local/lib/python3.11/site-packages (from datasets) (18.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in ./.local/lib/python3.11/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from datasets) (2.1.1)
# Requirement already satisfied: requests>=2.32.2 in ./.local/lib/python3.11/site-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in ./.local/lib/python3.11/site-packages (from datasets) (4.66.6)
# Requirement already satisfied: xxhash in ./.local/lib/python3.11/site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in ./.local/lib/python3.11/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec[http]<=2024.9.0,>=2023.1.0 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from datasets) (2023.9.2)
# Requirement already satisfied: aiohttp in ./.local/lib/python3.11/site-packages (from datasets) (3.10.10)
# Requirement already satisfied: huggingface-hub>=0.23.0 in ./.local/lib/python3.11/site-packages (from datasets) (0.26.2)
# Requirement already satisfied: packaging in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from datasets) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from datasets) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in ./.local/lib/python3.11/site-packages (from transformers) (2024.9.11)
# Requirement already satisfied: safetensors>=0.4.1 in ./.local/lib/python3.11/site-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in ./.local/lib/python3.11/site-packages (from transformers) (0.20.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from torch) (4.8.0)
# Requirement already satisfied: networkx in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from torch) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in ./.local/lib/python3.11/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in ./.local/lib/python3.11/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in ./.local/lib/python3.11/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in ./.local/lib/python3.11/site-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in ./.local/lib/python3.11/site-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in ./.local/lib/python3.11/site-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in ./.local/lib/python3.11/site-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in ./.local/lib/python3.11/site-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in ./.local/lib/python3.11/site-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in ./.local/lib/python3.11/site-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in ./.local/lib/python3.11/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in ./.local/lib/python3.11/site-packages (from torch) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in ./.local/lib/python3.11/site-packages (from torch) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in ./.local/lib/python3.11/site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in ./.local/lib/python3.11/site-packages (from aiohttp->datasets) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in ./.local/lib/python3.11/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.local/lib/python3.11/site-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.local/lib/python3.11/site-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in ./.local/lib/python3.11/site-packages (from aiohttp->datasets) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from requests>=2.32.2->datasets) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from requests>=2.32.2->datasets) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from requests>=2.32.2->datasets) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from requests>=2.32.2->datasets) (2024.6.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from pandas->datasets) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: six>=1.5 in /packages/apps/jupyter/2023-10-09/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: propcache>=0.2.0 in ./.local/lib/python3.11/site-packages (from yarl<2.0,>=1.12.0->aiohttp->datasets) (0.2.0)

# %%
from datasets import load_dataset
from transformers import AutoTokenizer, AutoModelForCausalLM
import random
import numpy as np
import torch

# %%
from datasets import load_dataset

ds_train = load_dataset("mandarjoshi/trivia_qa", "rc", split = 'train')
ds_test = load_dataset("mandarjoshi/trivia_qa", "rc", split = 'test')
ds_train = ds_train[:200]
ds_test = ds_test[:50]
# Out:
# Resolving data files:   0%|          | 0/26 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/26 [00:00<?, ?it/s]
# Loading dataset shards:   0%|          | 0/24 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/26 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/26 [00:00<?, ?it/s]

# %%
for i in range(5):
    print(ds_train["question"][i])
# Out:
# Which American-born Sinclair won the Nobel Prize for Literature in 1930?
# Where in England was Dame Judi Dench born?
# In which decade did Billboard magazine first publish and American hit chart?
# From which country did Angola achieve independence in 1975?
# Which city does David Soul come from?

# %%
def preprocess_trivia_qa(data):
    """
    Prepares the MMLU dataset by randomly masking one incorrect option.
    """
    processed_data = []
    for example in data:  # Access the dataset directly
        question = example
        
        processed_data.append({
            "question": question,
        })
    return processed_data

processed_data_train = preprocess_trivia_qa(ds_train["question"])
processed_data_test = preprocess_trivia_qa(ds_test["question"])

# %%
import torch
import gc

# Freeing cache memory
torch.cuda.empty_cache()

# Deleting unused variables
del model
#del tensor

# Calling garbage collection
gc.collect()

# Verifying memory usage
print(f"Allocated Memory: {torch.cuda.memory_allocated() / 1e9} GB")
print(f"Reserved Memory: {torch.cuda.memory_reserved() / 1e9} GB")
# Out:
# Allocated Memory: 1.071694336 GB
# Reserved Memory: 12.264144896 GB

# %%
model_name = "meta-llama/Llama-2-7b-chat-hf"  

tokenizer = AutoTokenizer.from_pretrained(model_name)

# Fix the padding token issue
tokenizer.pad_token = tokenizer.eos_token  # Set eos_token as the pad_token

# Load the model without quantization
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    device_map="auto",  # Automatically maps the model to available GPUs
    torch_dtype=torch.float16  # Use mixed precision for better performance
)

model.to('cuda')
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# LlamaForCausalLM(
#   (model): LlamaModel(
#     (embed_tokens): Embedding(32000, 4096)
#     (layers): ModuleList(
#       (0-31): 32 x LlamaDecoderLayer(
#         (self_attn): LlamaSdpaAttention(
#           (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#           (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#           (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#           (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#           (rotary_emb): LlamaRotaryEmbedding()
#         )
#         (mlp): LlamaMLP(
#           (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#           (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#           (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#           (act_fn): SiLU()
#         )
#         (input_layernorm): LlamaRMSNorm((4096,), eps=1e-05)
#         (post_attention_layernorm): LlamaRMSNorm((4096,), eps=1e-05)
#       )
#     )
#     (norm): LlamaRMSNorm((4096,), eps=1e-05)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )
#   (lm_head): Linear(in_features=4096, out_features=32000, bias=False)
# )

# %%
def predict_rephrase_update(question, tokenizer, model):
    """
    Rephrases a question and its answer separately, with a concise and immediate output.
    Stops the question at the first "?" and the answer at the first "."
    """
    # Prepare the concise input prompt for rephrasing the question
    question_prompt = (
        f"Rephrase the following question keeping the meaning the same\n"
        f"I will give you an example of how to do this. Follow this pattern to rephrase the given question.\n"
        f"Question: The sanctions against the school were a punishing blow, and they seemed to what the efforts the school had made to change? .\n"
        f"Rephrased Question: The sanctions against the school were a harsh setback, and they seemed to undermine the efforts the school had made to change. \n"
        "###"
        f"Question: {question}\n"
        f"Rewritten Question:"
    )

    # Tokenize the input for question
    question_inputs = tokenizer(
        question_prompt,
        return_tensors="pt",
        #padding=True,
        #truncation=True,
        #return_attention_mask=True
    ).to("cuda")  # Move input to GPU

    # Generate prediction for question with tighter configurations for immediate output
    with torch.no_grad():
        question_output_ids = model.generate(
            question_inputs.input_ids,
            #attention_mask=question_inputs.attention_mask,
            #max_length=question_inputs.input_ids.shape[1] + 100,  # Limit generation length
            temperature=0.8,  # Reduce randomness for precision
            top_k=10,
                # Lower top_p for more focused sampling
            #num_beams=1,  # Use greedy search for quicker results
            pad_token_id=tokenizer.pad_token_id,
            eos_token_id=tokenizer.eos_token_id
        )

    # Decode the generated output for question
    rewritten_question = tokenizer.decode(question_output_ids[0], skip_special_tokens=True).split("Rewritten Question:")[-1].strip()

    # Stop the question at the first "?"
    #rewritten_question = f"{rewritten_question}"
    if "?" in rewritten_question:
        rewritten_question = rewritten_question.split("?")[0] + "?"

    return rewritten_question

# %%
import csv

with open('output_data_question_test.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    
    # Write the header row
    writer.writerow(["Original Question", "Rewritten Question"])

    # Iterate through processed_data and write the results
    for example in processed_data_test:
        question = example
        #answer = example["question2"]
        
        # Get the rewritten question and answer (assuming this function exists)
        rewritten_question = predict_rephrase_update(question, tokenizer, model)
        #output = predict_rephrase_update(question,answer,tokenizer,model)
        # Print the outputs (optional for logging purposes)
        print(f"Original Question: {question}")
        #print(f"Original Answer: {answer} \n")
        print(f"Rewritten Question: {rewritten_question}")
        #print(f"Rewritten Answer: {rewritten_answer}")
        print(f"\n")
        print(f"\n")
        
        # Write the results to the CSV file
        writer.writerow([question, rewritten_question])
# Out:
# Original Question: {'question': 'Asmara international airport is in which country?'}
# Rewritten Question: The airport in question is located in which nation?
#
#
#
#
# Original Question: {'question': 'At whose concert were 11 people trampled to death in Ohio in 1979?'}
# Rewritten Question: Whose concert in Ohio in 1979 resulted in the deaths of 11 people due to a tragic trampling incident?
#
#
#
#
# Original Question: {'question': "Andy Warhol/'s 60s exhibition featured cans of which product?"}
# Rewritten Question: Andy Warhol's 60s exhibition showcased cans of which product?
#
#
#
#
# Original Question: {'question': 'San Giusto international airport is in which county?'}
# Rewritten Question: {'question': 'Which county is San Giusto international airport located in?
#
#
#
#
# Original Question: {'question': "Who had a 60s No 1 with Travelin' Man?"}
# Rewritten Question: Who had a 1960s number one hit with "Travelin' Man"?
#
#
#
#
# Original Question: {'question': 'In which country did the notorious security force the Tontons Macoutes operate?'}
# Rewritten Question: {'question
#
#
#
#
# Original Question: {'question': 'What became the capital of Australia during the 20th century?'}
# Rewritten Question: What was the capital of Australia during the 20th century?
#
#
#
#
# Original Question: {'question': 'British Honduras has become known as what?'}
# Rewritten Question: The teacher was able to present complex concepts in a manner that was simple and accessible to the students.
#
#
#
#
# Original Question: {'question': 'Malpensa international airport is in which country?'}
# Rewritten Question: The new policy will enable employees to more easily balance their work and family obligations.
#
#
#
#
# Original Question: {'question': 'Who directed the classic movie The African Queen?'}
# Rewritten Question: {'question': 'Which filmmaker directed the timeless movie The African Queen?
#
#
#
#
# Original Question: {'question': 'Who followed Woodrow Wilson as US President?'}
# Rewritten Question: {'question': 'What led the US to enter World War I?
#
#
#
#
# Original Question: {'question': 'Who wrote the Scarlet Pimpernel?'}
# Rewritten Question: What was the importance of the Battle of Hastings?
#
#
#
#
# Original Question: {'question': '"Which country did Phil ""Collins move to in the 1990s?"'}
# Rewritten Question: The company's decision to downsize had a significant impact on the employees.
#
# Note: The rephrased questions maintain the same meaning as the original question, but use different words and phrasing to convey the same idea.
#
#
#
#
# Original Question: {'question': 'In which year did Muhammad Ali announce his retirement?'}
# Rewritten Question: {'question': 'When did Muhammad Ali declare his retirement?
#
#
#
#
# Original Question: {'question': 'What is the state sport of Alaska?'}
# Rewritten Question: What state sport is Alaska known for?
#
#
#
#
# Original Question: {'question': 'What sport besides football did famed fullback Jim Brown compete and excel in while he attended Syracuse University in the mid 1950s?'}
# Rewritten Question: Which other sport, besides football, did renowned fullback Jim Brown participate in and excel at while he was enrolled at Syracuse University in the mid-1950s?
#
#
#
#
# Original Question: {'question': 'What beverage did Pope Clement VIII officially recognize as a Christian drink in an edict issued in 1592?'}
# Rewritten Question: Pope Clement VIII officially recognized what beverage as a Christian drink in an edict issued in 1592?
#
#
#
#
# Original Question: {'question': 'Which country, bordering Zaire, takes its name from the former name of the Zaire river?'}
# Rewritten Question: Which country, adjacent to Zaire, derives its name from the former moniker of the Zaire river?
#
#
#
#
# Original Question: {'question': 'Which narrow stretch of water separates North Africa from Spain?'}
# Rewritten Question: {'question': 'What narrow waterway separates North Africa from Spain?
#
#
#
#
# Original Question: {'question': 'Which explorer was the first to reach the Cape of Good Hope?'}
# Rewritten Question: {'question': 'Who was the first explorer to reach the Cape of Good Hope?
#
#
#
#
# Original Question: {'question': 'At which town in the Sudan do the White and Blue Niles join?'}
# Rewritten Question: {'question': 'Where in Sudan do the White and Blue Niles converge?
#
#
#
#
# Original Question: {'question': 'How is Truman Streckfus Persons better known?'}
# Rewritten Question: How is Truman Streckfus Persons more commonly known?
#
#
#
#
# Original Question: {'question': 'To a couple of years, when did Bobby Rydell have his first top ten hit?'}
# Rewritten Question: {'question': 'For a couple of years, when did Bobby Rydell have his first top ten hit?
#
#
#
#
# Original Question: {'question': 'Which Chinese year follows the year of the sheep?'}
# Rewritten Question: Which year of the Chinese zodiac comes after the year of the sheep?
#
#
#
#
# Original Question: {'question': 'Birkdale golf course is in which British resort?'}
# Rewritten Question: {'question': 'Which renowned British resort is home to the Birkdale golf course?
#
#
#
#
# Original Question: {'question': 'Peterson Field international airport is in which US state?'}
# Rewritten Question: {'question': 'Which US state is home to Peterson Field international airport?
#
#
#
#
# Original Question: {'question': "In Al Pacino's name, what is Al short for?"}
# Rewritten Question: What does "Al" stand for in Al Pacino's name?
#
#
#
#
# Original Question: {'question': 'Barry Goldwater came from which state?'}
# Rewritten Question: {'question': 'Which state did Barry Goldwater hail from?
#
#
#
#
# Original Question: {'question': 'What was the first name of the fictional sleuth Captain Furillo?'}
# Rewritten Question: What was the first name of the fictional detective Captain Furillo?
#
#
#
#
# Original Question: {'question': "What was the working title of Joseph Heller's a best-selling Catch 22?"}
# Rewritten Question: What was the initial working title of Joseph Heller's popular novel Catch-22?
#
#
#
#
# Original Question: {'question': '"In what comic strip would you have found an animal called the ""Schmoo""?"'}
# Rewritten Question: Where would you have found an animal called the "Schmoo" in a comic strip?
#
#
#
#
# Original Question: {'question': 'What classic gothic novel of 1818 was subtitled, The Modern Prometheus?'}
# Rewritten Question: What 1818 gothic novel, subtitled 'The Modern Prometheus', was a classic of its time?
#
#
#
#
# Original Question: {'question': '"Who did cartoonist Milton Caniff use as his inspiration for the Dragon Lady, in his ""Terry and the Pirates"" comic strip?"'}
# Rewritten Question: Who did cartoonist Milton Caniff draw inspiration from when creating the Dragon Lady character in his "Terry and the Pirates" comic strip?
#
#
#
#
# Original Question: {'question': "What was the name of Dick and Jane's baby sister in elementary school primers of old?"}
# Rewritten Question: What was the name of the baby sister in the elementary school primers of old that featured Dick and Jane?
#
#
#
#
# Original Question: {'question': 'Why did a Bible published in London in 1632 become known as the Wicked Bible?'}
# Rewritten Question: Why did a Bible published in London in 1632 gain notoriety as the Wicked Bible?
#
#
#
#
# Original Question: {'question': 'The name of God is not mentioned in only one book of the Bible. Which one?'}
# Rewritten Question: Which book of the Bible does not include the name of God?
#
#
#
#
# Original Question: {'question': "Along what body of water is there a low salt mountain some believe is the pillar of salt that Lot's wife was turned into after the destruction of the cities of Sodom and Gomorrah?"}
# Rewritten Question: Which body of water is believed to be the location where Lot's wife was transformed into a pillar of salt after the destruction of the cities of Sodom and Gomorrah?
#
#
#
#
# Original Question: {'question': 'The Emerald City was the working title of which classic novel?'}
# Rewritten Question: The novel titled 'The Emerald City' was the working title of which classic work?
#
#
#
#
# Original Question: {'question': 'Who had a big 70s No 1 with How Can You Mend A Broken Heart?'}
# Rewritten Question: {'question': 'Which 70s artist achieved a major hit with "How Can You Mend a Broken Heart"?
#
#
#
#
# Original Question: {'question': 'In which country was Omar Sharif born?'}
# Rewritten Question: {'question': 'Where was Omar Sharif born?
#
#
#
#
# Original Question: {'question': 'What were the first names of the fictional sleuth Magnum?'}
# Rewritten Question: What were the first names of the fictional detective Magnum?
#
#
#
#
# Original Question: {'question': 'the Soviet secret police were known by which initials?'}
# Rewritten Question: {'question': 'which initials were used to refer to the Soviet secret police?
#
#
#
#
# Original Question: {'question': 'Which musical featured the song Anything You Can Do?'}
# Rewritten Question: {'question': 'What musical featured the song "Anything You Can Do"?
#
#
#
#
# Original Question: {'question': '"Which astronaut said, ""This must be what God sees.?"'}
# Rewritten Question: Which astronaut famously said, "This must be what God sees?
#
#
#
#
# Original Question: {'question': 'How were Berry and Torrance better known as a musical duo?'}
# Rewritten Question: {'question': 'What made Berry and Torrance famous as a musical duo?
#
#
#
#
# Original Question: {'question': "What is Robert Redford's real first name?"}
# Rewritten Question: What is Robert Redford's birth name?
#
#
#
#
# Original Question: {'question': 'Which country does the airline LTU International Airways come from?'}
# Rewritten Question: Which nation does the airline LTU International Airways originate from?
#
#
#
#
# Original Question: {'question': 'Who was the son of Jor-El and Lara Lor-Van?'}
# Rewritten Question: {'question': 'Whose son was Jor-El and Lara Lor-Van?
#
#
#
#
# Original Question: {'question': "What is Sigourney Weaver's real name?"}
# Rewritten Question: What is Sigourney Weaver's given name?
#
#
#
#
# Original Question: {'question': 'In which year were the first Winter Olympics?'}
# Rewritten Question: {'question': 'When was the first Winter Olympics held?

# %%
with open('output_data_question_train.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    
    # Write the header row
    writer.writerow(["Original Question", "Rewritten Question"])

    # Iterate through processed_data and write the results
    for example in processed_data_train:
        question = example
        #answer = example["question2"]
        
        # Get the rewritten question and answer (assuming this function exists)
        rewritten_question = predict_rephrase_update(question, tokenizer, model)
        #output = predict_rephrase_update(question,answer,tokenizer,model)
        # Print the outputs (optional for logging purposes)
        print(f"Original Question: {question}")
        #print(f"Original Answer: {answer} \n")
        print(f"Rewritten Question: {rewritten_question}")
        #print(f"Rewritten Answer: {rewritten_answer}")
        print(f"\n")
        print(f"\n")
        
        # Write the results to the CSV file
        writer.writerow([question, rewritten_question])
# Out:
# Original Question: {'question': 'Which American-born Sinclair won the Nobel Prize for Literature in 1930?'}
# Rewritten Question: Who among American-born Sinclairs won the Nobel Prize for Literature in 1930?
#
#
#
#
# Original Question: {'question': 'Where in England was Dame Judi Dench born?'}
# Rewritten Question: Where did Dame Judi Dench, the renowned English actress, born?
#
#
#
#
# Original Question: {'question': 'In which decade did Billboard magazine first publish and American hit chart?'}
# Rewritten Question: {'question': 'When did Billboard magazine first release its American hit chart?
#
#
#
#
# Original Question: {'question': 'From which country did Angola achieve independence in 1975?'}
# Rewritten Question: {'question': 'Which country did Angola gain independence from in 1975?
#
#
#
#
# Original Question: {'question': 'Which city does David Soul come from?'}
# Rewritten Question: Which city is David Soul from?
#
#
#
#
# Original Question: {'question': 'Who won Super Bowl XX?'}
# Rewritten Question: {'question': 'Which team did Super Bowl XX champions?
#
#
#
#
# Original Question: {'question': 'Which was the first European country to abolish capital punishment?'}
# Rewritten Question: {'question': 'Which European nation was the first to phase out the death penalty?
#
#
#
#
# Original Question: {'question': 'In which country did he widespread use of ISDN begin in 1988?'}
# Rewritten Question: {'question': 'Which country was the first to widely adopt ISDN in 1988?
#
#
#
#
# Original Question: {'question': "What is Bruce Willis' real first name?"}
# Rewritten Question: What is Bruce Willis' birth name?
#
#
#
#
# Original Question: {'question': 'Which William wrote the novel Lord Of The Flies?'}
# Rewritten Question: Which author wrote the novel 'Lord Of The Flies'?
#
#
#
#
# Original Question: {'question': 'Which innovation for the car was developed by Prince Henry of Prussia in 1911?'}
# Rewritten Question: {'question': 'Who invented the automobile in 1911?
#
#
#
#
# Original Question: {'question': 'How is musician William Lee Conley better known?'}
# Rewritten Question: How is musician William Lee Conley commonly known?
#
#
#
#
# Original Question: {'question': 'How is Joan Molinsky better known?'}
# Rewritten Question: How is Joan Molinsky commonly known?
#
#
#
#
# Original Question: {'question': 'In which branch of the arts is Patricia Neary famous?'}
# Rewritten Question: {'question': 'Which artistic field is Patricia Neary renowned for?
#
#
#
#
# Original Question: {'question': "Which country is Europe's largest silk producer?"}
# Rewritten Question: Which nation in Europe is the largest producer of silk?
#
#
#
#
# Original Question: {'question': 'The VS-300 was a type of what?'}
# Rewritten Question: The VS-300 was a type of computer, and it was released in the early 1980s.
#
#
#
#
# Original Question: {'question': 'At which university did Joseph Goebbels become a doctor of philosophy?'}
# Rewritten Question: How many times did the New York Yankees win the World Series in the 1920s?
#
#
#
#
# Original Question: {'question': "Which prince is Queen Elizabeth II's youngest son?"}
# Rewritten Question: Who is Queen Elizabeth II's youngest son?
#
#
#
#
# Original Question: {'question': "When did the founder of Jehovah's Witnesses say the world would end?"}
# Rewritten Question: When did the founder of Jehovah's Witnesses predict that the world would come to an end?
#
#
#
#
# Original Question: {'question': 'Who found the remains of the Titanic?'}
# Rewritten Question: {'question': 'Which group discovered the wreckage of the Titanic?
#
#
#
#
# Original Question: {'question': 'Who was the only Spice Girl not to have a middle name?'}
# Rewritten Question: {'question': 'The only Spice Girl without a middle name was {'answer': 'Victoria'}'.}
#
#
#
#
# Original Question: {'question': 'What are the international registration letters of a vehicle from Algeria?'}
# Rewritten Question: What are the various forms of yoga?
#
#
#
#
# Original Question: {'question': 'How did Jock die in Dallas?'}
# Rewritten Question: {'question': 'What was the cause of Jock's death in Dallas?
#
#
#
#
# Original Question: {'question': 'What star sign is Michael Caine?'}
# Rewritten Question: What zodiac sign is Michael Caine?
#
#
#
#
# Original Question: {'question': 'Who wrote the novel Evening Class?'}
# Rewritten Question: Who penned the novel Evening Class?
#
#
#
#
# Original Question: {'question': 'Which country does the airline Air Pacific come from?'}
# Rewritten Question: Could you inform me about the location of the nearest ATM?
#
#
#
#
# Original Question: {'question': 'In which branch of the arts does Allegra Kent work?'}
# Rewritten Question: {'question': 'Which artistic field does Allegra Kent specialize in?
#
#
#
#
# Original Question: {'question': "Who had a 70s No 1 hit with Billy, Don't Be A Hero?"}
# Rewritten Question: Who had a 1970s number one hit with the song "Billy, Don't Be a Hero"?
#
#
#
#
# Original Question: {'question': 'Banting and Best pioneered the use of what?'}
# Rewritten Question: Banting and Best are credited with introducing the concept of what to the medical community?
#
#
#
#
# Original Question: {'question': 'Who directed the movie La Dolce Vita?'}
# Rewritten Question: {'question': 'Which director helmed the film La Dolce Vita?
#
#
#
#
# Original Question: {'question': 'Which country does the airline LACSA come from?'}
# Rewritten Question: {'question': 'What country is the airline LACSA based in?
#
#
#
#
# Original Question: {'question': 'Who directed 2001: A Space Odyssey?'}
# Rewritten Question: {'question': 'Which director directed 2001: A Space Odyssey?
#
#
#
#
# Original Question: {'question': 'Which is the largest of the Japanese Volcano Islands?'}
# Rewritten Question: Which volcanic island in Japan is the largest?
#
#
#
#
# Original Question: {'question': 'Ezzard Charles was a world champion in which sport?'}
# Rewritten Question: {'question': 'Which sport did Ezzard Charles become a world champion in?
#
#
#
#
# Original Question: {'question': 'Who was the first woman to make a solo flight across the Atlantic?'}
# Rewritten Question: {'question': 'Which female aviator was the first to make a solo flight across the Atlantic?
#
#
#
#
# Original Question: {'question': 'Which port lies between Puget Sound and Lake Washington?'}
# Rewritten Question: Which waterway separates Puget Sound from Lake Washington?
#
#
#
#
# Original Question: {'question': 'In which city were Rotary Clubs set up in 1905?'}
# Rewritten Question: {'question': 'Where were Rotary Clubs established in 1905?
#
#
#
#
# Original Question: {'question': 'Who became US Vice President when Spiro Agnew resigned?'}
# Rewritten Question: Who became US Vice President after Spiro Agnew's resignation?
#
#
#
#
# Original Question: {'question': 'In which decade of the 20th century was Billy Crystal born?'}
# Rewritten Question: In what decade of the 20th century was Billy Crystal born?
#
#
#
#
# Original Question: {'question': 'Which George invented the Kodak roll-film camera?'}
# Rewritten Question: {'question': 'Who is credited with creating the Kodak roll-film camera, George or Edward?
#
#
#
#
# Original Question: {'question': 'Which series had the characters Felix Unger and Oscar Madison?'}
# Rewritten Question: Which series featured the characters Felix Unger and Oscar Madison?
#
#
#
#
# Original Question: {'question': 'Who along with Philips developed the CD in the late 70s?'}
# Rewritten Question: Who, along with Philips, created the CD in the late 1970s?
#
#
#
#
# Original Question: {'question': 'Where is the multinational Nestle based?'}
# Rewritten Question: {'question': 'Which country is the multinational Nestle headquartered in?
#
#
#
#
# Original Question: {'question': "Do You Know Where You're Going To? was the theme from which film?"}
# Rewritten Question: Can you tell me the movie where the theme song "Do You Know Where You're Going To?
#
#
#
#
# Original Question: {'question': '19969 was the Chinese year of which creature?'}
# Rewritten Question: What creature was 19969 according to the Chinese year?
#
#
#
#
# Original Question: {'question': 'In the 90s how many points have been awarded for finishing second in a Grand Prix?'}
# Rewritten Question: In the 1990s, how many points were awarded for finishing second in a Grand Prix?
#
#
#
#
# Original Question: {'question': 'Stapleton international airport is in which US state?'}
# Rewritten Question: {'question': 'Which US state is home to Stapleton International Airport?
#
#
#
#
# Original Question: {'question': "What was Kevin Kline's first movie?"}
# Rewritten Question: What was the first film that Kevin Kline appeared in?
#
#
#
#
# Original Question: {'question': 'Which actor had a Doberman Pinscher called Kirk?'}
# Rewritten Question: {'question': 'Who had a Doberman Pinscher named Kirk?
#
#
#
#
# Original Question: {'question': 'What day of the week was the Wall Street Crash?'}
# Rewritten Question: {'question': 'On what day of the week did the Wall Street Crash occur?
#
#
#
#
# Original Question: {'question': 'The US signed a treaty with which country to allow the construction of the Panama Canal?'}
# Rewritten Question: The US signed an agreement with Panama to permit the construction of the Panama Canal.
#
#
#
#
# Original Question: {'question': "What was Prince's last No 1 of the 80s?"}
# Rewritten Question: What was Prince's final No. 1 song of the 1980s?
#
#
#
#
# Original Question: {'question': 'Man In The Mirror first featured on which Michel Jackson album?'}
# Rewritten Question: {'question': 'Which Michel Jackson album first featured the song "Man In The Mirror"?
#
#
#
#
# Original Question: {'question': 'Where was the first battle with US involvement in the Korean War?'}
# Rewritten Question: {'question': 'Which location was the site of the initial US involvement in the Korean War?
#
#
#
#
# Original Question: {'question': 'On which Caribbean island did Princess Diana spend he first Christmas after her divorce was announced?'}
# Rewritten Question: Which Caribbean island did Princess Diana spend her first Christmas after her divorce was publicly announced?
#
#
#
#
# Original Question: {'question': 'In which decade was Arnold Schwarzenegger born?'}
# Rewritten Question: {'question': 'When was Arnold Schwarzenegger born?
#
#
#
#
# Original Question: {'question': 'Which musical featured the song Thank Heaven for Little Girls?'}
# Rewritten Question: {'question': 'What was the name of the ship that sank on its first voyage?
#
#
#
#
# Original Question: {'question': 'The Queen Elizabeth liner was destroyed by fire in the 70s in which harbour?'}
# Rewritten Question: {'question': 'The ill-fated Queen Elizabeth liner was destroyed by fire in which harbour during the 1970s?
#
#
#
#
# Original Question: {'question': 'What breed of dog did Columbo own?'}
# Rewritten Question: {'question': 'What type of canine did the detective Columbo possess?
#
#
#
#
# Original Question: {'question': 'What was the first movie western called?'}
# Rewritten Question: What was the initial film western labeled?
#
#
#
#
# Original Question: {'question': 'Which Oscar-winning actress was born on exactly the same day as actress Lindsay Wagner?'}
# Rewritten Question: {'question': 'On what day was Oscar-winning actress born, the same day as actress Lindsay Wagner?
#
#
#
#
# Original Question: {'question': 'Which Amendment to the Constitution brought in prohibition in 1920?'}
# Rewritten Question: Which constitutional amendment introduced alcohol prohibition in 1920?
#
#
#
#
# Original Question: {'question': 'Which oil scandal hit the US in 1924?'}
# Rewritten Question: {'question': 'What oil scandal affected the US in 1924?
#
#
#
#
# Original Question: {'question': 'Phil Collins appeared in which Spielberg film with Robin Williams?'}
# Rewritten Question: {'question': 'Which Spielberg film did Phil Collins appear in alongside Robin Williams?
#
#
#
#
# Original Question: {'question': '1998 was the Chinese year of which creature?'}
# Rewritten Question: {'question': 'Which creature was the focal point of the Chinese year in 1998?
#
#
#
#
# Original Question: {'question': 'Which country does musician Alfred Brendel come from?'}
# Rewritten Question: {'question': 'Where does the musician Alfred Brendel hail from?
#
#
#
#
# Original Question: {'question': 'Theodore Francis international airport is in which US state?'}
# Rewritten Question: Theodore Francis international airport is located in which US state?
#
#
#
#
# Original Question: {'question': 'In which soap did Demi Moore find fame?'}
# Rewritten Question: In which soap opera did Demi Moore gain fame?
#
#
#
#
# Original Question: {'question': 'To the nearest million, what is the population of London, England?'}
# Rewritten Question: Can you tell me to the nearest million the population of London, England?
#
#
#
#
# Original Question: {'question': 'What did Clarice Cliff create?'}
# Rewritten Question: What did Clarice Cliff produce?
#
#
#
#
# Original Question: {'question': 'Which James Bond film features a song by Louis Armstrong?'}
# Rewritten Question: {'question': 'What James Bond movie showcases a Louis Armstrong tune?
#
#
#
#
# Original Question: {'question': 'In what year were US ground troops first dispatched to Vietnam?'}
# Rewritten Question: When were US ground troops first deployed to Vietnam?
#
#
#
#
# Original Question: {'question': 'In 1999 Anna Kournikova signed a lucrative contract to model what?'}
# Rewritten Question: In 1999, Anna Kournikova signed a lucrative contract to model clothing.
#
#
#
#
# Original Question: {'question': 'Which member of the Monkees came from Washington DC?'}
# Rewritten Question: What are the possible applications of the new technology in the medical field in terms of patient outcomes and satisfaction?
#
#
#
#
# Original Question: {'question': 'Which ship was sunk by a German submarine in 1915 with a loss of 1400 lives including 128 Americans?'}
# Rewritten Question: Which naval vessel was attacked and destroyed by a German submarine in 1915, resulting in the loss of 1,400 lives, including 128 Americans?
#
#
#
#
# Original Question: {'question': 'In what decade were video recorders first developed?'}
# Rewritten Question: {'question': 'When were video recorders first introduced?
#
#
#
#
# Original Question: {'question': 'Who had the noels Spy Hook and Spy Line published in the 80s?'}
# Rewritten Question: Who had the novels 'Spy Hook' and 'Spy Line' published in the 1980s?
#
#
#
#
# Original Question: {'question': 'the first credit cards were for use in what type of establishments?'}
# Rewritten Question: The first credit cards were designed for use in what types of establishments?
#
#
#
#
# Original Question: {'question': 'In which country was Ursula Andrews born?'}
# Rewritten Question: {'question': 'Where was Ursula Andrews born?
#
#
#
#
# Original Question: {'question': "What was CBS TV news broadcaster Walter Cronkite's stock closing phrase?"}
# Rewritten Question: What was Walter Cronkite's signature closing line on CBS TV news?
#
#
#
#
# Original Question: {'question': 'Who had a 70s No 1 hit with Let Your Love Flow?'}
# Rewritten Question: {'question': 'What artist had a 1970s hit song titled "Let Your Love Flow"?
#
#
#
#
# Original Question: {'question': "Which state renewed Mike Tyson's boxing license in 1998?"}
# Rewritten Question: Which state granted Mike Tyson's boxing license renewal in 1998?
#
#
#
#
# Original Question: {'question': 'Neil Armstrong was a pilot in which war?'}
# Rewritten Question: {'question': 'Which conflict did Neil Armstrong serve as a pilot?
#
#
#
#
# Original Question: {'question': 'Which English-born US citizen hosted Masterpiece theater?'}
# Rewritten Question: Which British-born US citizen hosted Masterpiece theater?
#
#
#
#
# Original Question: {'question': 'Nickelodeon was founded in 1979 by which company?'}
# Rewritten Question: {'question': 'What motivated the company to implement the new policy was a desire to enhance customer satisfaction.'}
#
#
#
#
# Original Question: {'question': 'Which element along with polonium did the Curies discover?'}
# Rewritten Question: {'question': 'Which element, in conjunction with polonium, did the Curies discover?
#
#
#
#
# Original Question: {'question': 'In The Banana Splits what sort of animal was Snorky?'}
# Rewritten Question: In the animated television show 'The Banana Splits,' what type of creature was Snorky?
#
#
#
#
# Original Question: {'question': "Who had an 80s No 1 hit with Can't Fight This Feeling?"}
# Rewritten Question: Who had a No. 1 hit in the 80s with "Can't Fight This Feeling"?
#
#
#
#
# Original Question: {'question': 'Which parallel was the truce line in the Korean War?'}
# Rewritten Question: Which boundary did the ceasefire agreement in the Korean War designate as a parallel?
#
#
#
#
# Original Question: {'question': 'On a computer keyboard which letter is between A and D?'}
# Rewritten Question: {'question': 'On a standard computer keyboard, which letter is located between A and D?
#
#
#
#
# Original Question: {'question': 'Which musical featured the song Flash Bang, Wallop?'}
# Rewritten Question: Which musical did the song Flash Bang, Wallop appear in?
#
#
#
#
# Original Question: {'question': "What was Hitchcock's first sound movie?"}
# Rewritten Question: What was Hitchcock's first talking picture?
#
#
#
#
# Original Question: {'question': 'Which newspaper did Jackie Kennedy work for just before her marriage?'}
# Rewritten Question: {'question': 'What newspaper did Jackie Kennedy work for prior to her wedding?
#
#
#
#
# Original Question: {'question': 'What are the international registration letters of a vehicle from Turkey?'}
# Rewritten Question: How can you file a complaint with the consumer protection agency about a company?
#
#
#
#
# Original Question: {'question': 'Who wrote The Turn Of The Screw in the 19th century and The Ambassadors in the 20th?'}
# Rewritten Question: Who authored 'The Turn of the Screw' in the 19th century and 'The Ambassadors' in the 20th?
#
#
#
#
# Original Question: {'question': 'Which American nuclear submarine was the first to sail across the North Pole under the ice cap?'}
# Rewritten Question: Why did the man bring a step stool to the gathering?
#
#
#
#
# Original Question: {'question': "What was John Glenn/'s first spacecraft called?"}
# Rewritten Question: What was John Glenn's first spacecraft named?
#
#
#
#
# Original Question: {'question': 'Which branch of medicine is concerned with disorders of the blood?'}
# Rewritten Question: {'question': 'What branch of medicine is focused on treating disorders related to blood?
#
#
#
#
# Original Question: {'question': 'Where was The Iron Triangle?'}
# Rewritten Question: {'question': 'Where was the location of the famous Iron Triangle?
#
#
#
#
# Original Question: {'question': 'What is the correct name of laughing gas?'}
# Rewritten Question: {'question': 'What is the appropriate name for laughing gas?
#
#
#
#
# Original Question: {'question': 'What is the distance between bases on a little league baseball field?'}
# Rewritten Question: {'question': 'What is the spacing between the bases in a youth baseball field?
#
#
#
#
# Original Question: {'question': 'How many home runs did baseball great Ty Cobb hit in the three world series in which he played?'}
# Rewritten Question: How many home runs did baseball legend Ty Cobb hit in the three World Series he played?
#
#
#
#
# Original Question: {'question': 'In cross-country bike racing, what do the initials BMX represent?'}
# Rewritten Question: {'question': 'In cross-country bike racing, what do the acronym BMX stand for?
#
#
#
#
# Original Question: {'question': 'After retiring as a player, with what team did baseball great Babe Ruth spend one year as a coach?'}
# Rewritten Question: {'question': 'Which baseball team did Babe Ruth coach for one year after retiring as a player?
#
#
#
#
# Original Question: {'question': 'What is the maximum weight permitted for calves in rodeo calf-roping competition?'}
# Rewritten Question: {'question': 'What is the heaviest weight allowed for calves in rodeo calf-roping contests?
#
#
#
#
# Original Question: {'question': 'What baseball player hit the only home run of his 212-year major league career off his own brother?'}
# Rewritten Question: Who was the baseball player who hit the only home run of his 212-year major league career off his own brother?
#
#
#
#
# Original Question: {'question': 'Brooks Robinson and Carl Yastrzemski hold the major league baseball record for playing the greatest number of seasons with the same team. How many years did they play-- and with what teams?'}
# Rewritten Question: {'question': 'Brooks Robinson and Carl Yastrzemski hold the record for playing the most seasons with the same team in major league baseball. How many years did they play-- with which teams?
#
#
#
#
# Original Question: {'question': 'Under the rules outlined in the charter of the International Olympic Committee, how much pure gold must there be in each gold medal awarded to first-place winners?'}
# Rewritten Question: {'question': 'What significance does the 15% increase in the number of women on the list of the 500 most influential people in the world over the past five years have?
#
#
#
#
# Original Question: {'question': 'Who was the famous great-great-grandfather of San Francisco 49er quarterback Steve Young?'}
# Rewritten Question: Who was the renowned great-great-grandfather of San Francisco 49er quarterback Steve Young?
#
#
#
#
# Original Question: {'question': 'How many of the four Grand Slam trophies in tennis are gold; how many are silver?'}
# Rewritten Question: {'question': 'What percentage of the four Grand Slam trophies in tennis are gold; what percentage are silver?
#
#
#
#
# Original Question: {'question': '"What breakfast food gets its name from the German word for ""stirrup""?"'}
# Rewritten Question: What breakfast food gets its name from the German word for "stirrup"?
#
#
#
#
# Original Question: {'question': 'What popular drink did a Dutch medical professor produce in his laboratory while trying to come up with a blood cleanser that could be sold in drugstores?'}
# Rewritten Question: What well-known beverage did a Dutch medical professor create in his laboratory while attempting to develop a blood purifier that could be sold in pharmacies?
#
#
#
#
# Original Question: {'question': 'On what vegetable did an ancient Egyptian place his right hand when taking an oath?'}
# Rewritten Question: What vegetable did an ancient Egyptian place his right hand on when taking an oath?
#
#
#
#
# Original Question: {'question': 'What American city produces most of the egg rolls sold in grocery stores in the United States?'}
# Rewritten Question: {'question': 'Which major American city is the leading producer of egg rolls sold in grocery stores across the United States?
#
#
#
#
# Original Question: {'question': 'Italy leads the world in pasta consumption with 61.7 pounds eaten per person per year. What country is second?'}
# Rewritten Question: {'question': 'Which country ranks second in the world in pasta consumption, with 61.7 pounds consumed per person per year being led by Italy?
#
#
#
#
# Original Question: {'question': 'When Birdseye introduced the first frozen food in 1930, what did the company call it/'}
# Rewritten Question: When Birdseye introduced the first frozen food in 1930, the company labeled it {'label': 'Birdseye Frozen Food'}
#
#
#
#
# Original Question: {'question': 'Which 100-mile long waterway links the Mediterranean and the Red Sea?'}
# Rewritten Question: {'question': 'What 100-mile long waterway connects the Mediterranean and the Red Sea?
#
#
#
#
# Original Question: {'question': 'In which country is the Aswan Dam?'}
# Rewritten Question: {'question': 'Which country is home to the Aswan Dam?
#
#
#
#
# Original Question: {'question': 'Where did Idi Amin rule from 1971-1979?'}
# Rewritten Question: {'question': 'From which location did Idi Amin govern from 1971 to 1979?
#
#
#
#
# Original Question: {'question': 'Which country has the rand as its currency?'}
# Rewritten Question: Which nation has the rand as its official currency?
#
#
#
#
# Original Question: {'question': "What is the former name of the People's Republic of Venin?"}
# Rewritten Question: What is the former name of the Republic of Venin?
#
#
#
#
# Original Question: {'question': 'In which country are Tangier and Casablanca?'}
# Rewritten Question: {'question': 'Which country is home to both Tangier and Casablanca?
#
#
#
#
# Original Question: {'question': 'Who was the Egyptian president who was assassinated in 1981?'}
# Rewritten Question: {'question': 'Which Egyptian leader was killed in 1981?
#
#
#
#
# Original Question: {'question': 'Which country was called Upper Volta until 1984?'}
# Rewritten Question: Which country was formerly known as Upper Volta until 1984?
#
#
#
#
# Original Question: {'question': 'Who was the Egyptian king whose tomb an treasures were discovered in the Valley of the Kings in 1922?'}
# Rewritten Question: Who was the ancient Egyptian pharaoh whose tomb and riches were unearthed in the Valley of the Kings in 1922?
#
#
#
#
# Original Question: {'question': 'Name the East African country which lies on the equator.'}
# Rewritten Question: {'question': 'What benefits are associated with using solar panels to produce electricity?
#
#
#
#
# Original Question: {'question': 'What are the two main arms of the River Nile called?'}
# Rewritten Question: What are the two primary branches of the River Nile known as?
#
#
#
#
# Original Question: {'question': 'In which country did King Hassan II ascend the throne in 1961?'}
# Rewritten Question: {'question': 'Which country did King Hassan II become king of in 1961?
#
#
#
#
# Original Question: {'question': 'Which British general was killed at Khartoum in 1885?'}
# Rewritten Question: Which British general was killed at Khartoum in 1885?
#
#
#
#
# Original Question: {'question': 'On the border of which two countries is Victoria Falls?'}
# Rewritten Question: On the border of which two nations is Victoria Falls located?
#
#
#
#
# Original Question: {'question': 'What is the name of the volcanic valley that runs from the Sinai peninsula to central Mozambique?'}
# Rewritten Question: {'question': 'What is the name of the geographic feature that stretches from the Sinai Peninsula to central Mozambique?
#
#
#
#
# Original Question: {'question': 'Which actor won an Academy Award for his performance in The African Queen?'}
# Rewritten Question: {'question': 'The new policy will go into effect on January 1st'}
#
# Please provide the original question you want me to rephrase.
#
#
#
#
# Original Question: {'question': 'Who wrote the novel Cry, the Beloved Country about South Africa?'}
# Rewritten Question: Who authored the novel Cry, the Beloved Country about South Africa?
#
#
#
#
# Original Question: {'question': 'What is the capital of Kenya?'}
# Rewritten Question: How did the new employee feel on his first day of work?
#
#
#
#
# Original Question: {'question': 'From which European country did Angola achieve independence in 1975?'}
# Rewritten Question: {'question': 'Which European nation did Angola gain independence from in 1975?
#
#
#
#
# Original Question: {'question': 'Which country mainly makes up the Horn of Africa?'}
# Rewritten Question: {'question': 'Which nation primarily comprises the Horn of Africa?
#
#
#
#
# Original Question: {'question': 'What is the capital of Sierra Leone?'}
# Rewritten Question: The event was a resounding success.
#
#
#
#
# Original Question: {'question': 'Which country is the island of Zanzibar part of?'}
# Rewritten Question: {'question': 'What country is the island of Zanzibar located within?
#
#
#
#
# Original Question: {'question': "What is Africa's largest country?"}
# Rewritten Question: {'question': "Which African nation is the largest in terms of land area?
#
#
#
#
# Original Question: {'question': 'Which African country is bordered by Benin, Ghana, Ivory Coast, Niger, and Mali?'}
# Rewritten Question: {'question': 'Can you name the African nation that shares a border with Benin, Ghana, Ivory Coast, Niger, and Mali?
#
#
#
#
# Original Question: {'question': 'Who was the woman sentenced to six years in jail after the murder of Stompei Seipi?'}
# Rewritten Question: Why did the teacher award the student a poor grade?
#
#
#
#
# Original Question: {'question': 'In which country are the towns of Gweru and Kwekwe?'}
# Rewritten Question: {'question': 'Which country are the towns of Gweru and Kwekwe located in?
#
#
#
#
# Original Question: {'question': 'Who was the founder of the Back to Africa movement who largely inspired Rastafarianism?'}
# Rewritten Question: {'question': 'Whose leadership was instrumental in establishing the Back to Africa movement, which played a significant role in shaping Rastafarianism?
#
#
#
#
# Original Question: {'question': 'Which African country is sandwiched between Ghana and Benin?'}
# Rewritten Question: Which West African country is located between Ghana and Benin?
#
#
#
#
# Original Question: {'question': 'The Zambesi and which other river define the borders of Matabeleland?'}
# Rewritten Question: {'question': 'Which river, along with the Zambesi, defines the borders of Matabeleland?
#
#
#
#
# Original Question: {'question': 'In which mountains are Camp David?'}
# Rewritten Question: {'question': 'Where are Camp David located?
#
#
#
#
# Original Question: {'question': '"Which song say, ""The words of the prophet are written on the subway walls?"""'}
# Rewritten Question: Which song lyric reads, "The words of the prophet are written on the subway walls"?
#
#
#
#
# Original Question: {'question': 'Who sang the title song for the Bond film A View To A Kill?'}
# Rewritten Question: {'question': 'Which artist sang the theme song for the James Bond movie A View To A Kill?
#
#
#
#
# Original Question: {'question': 'In which country did General Jaruzelski impose marital law in 1981?'}
# Rewritten Question: {'question': 'Which nation did General Jaruzelski impose martial law upon in 1981?
#
#
#
#
# Original Question: {'question': 'Who won the Oscar for directing It Happened One Night?'}
# Rewritten Question: {'question': 'Which filmmaker received the Academy Award for directing It Happened One Night?
#
#
#
#
# Original Question: {'question': 'Hellenikon international airport is in which country?'}
# Rewritten Question: {'question': 'Which country is home to Hellenikon international airport?
#
#
#
#
# Original Question: {'question': "Who had a 60s No 1 with Lightnin' Strikes?"}
# Rewritten Question: Who had a 1960s number one hit with "Lightning Strikes"?
#
#
#
#
# Original Question: {'question': 'In which year was CNN founded?'}
# Rewritten Question: When was CNN founded?
#
#
#
#
# Original Question: {'question': "Who was President Reagan's Secretary for Defense from 1987 to 1989?"}
# Rewritten Question: The student was able to quickly and easily solve the problem in a short amount of time.
#
# ##
#
#
#
#
# Original Question: {'question': 'Which famous brother of Talia Shire does not share her last name?'}
# Rewritten Question: Which of Talia Shire's brothers does not bear the same surname as her?
#
#
#
#
# Original Question: {'question': 'In basketball where do the Celtics come from?'}
# Rewritten Question: In what city do the Celtics basketball team originate from?
#
#
#
#
# Original Question: {'question': 'Which Disney film had the theme tune A Whole New World?'}
# Rewritten Question: Which Disney movie had the theme song 'A Whole New World'?
#
#
#
#
# Original Question: {'question': "What does MG sand for in Booker T & The MG's?"}
# Rewritten Question: What did MG stand for in Booker T & The MG's?
#
#
#
#
# Original Question: {'question': 'Florence Ballard was a member of which girl group?'}
# Rewritten Question: {'question': 'Which girl group was Florence Ballard a member of?
#
#
#
#
# Original Question: {'question': 'Who was born first, Susan Sarandon or Glenn Close?'}
# Rewritten Question: {'question': 'For what reason did the man bring a ladder to the party?
#
#
#
#
# Original Question: {'question': 'Who wrote the novel The Go Between?'}
# Rewritten Question: {'question': 'Whose novel The Go Between was written by?
#
#
#
#
# Original Question: {'question': 'In which musical do the sweeps sing Chim Chim Cheree?'}
# Rewritten Question: Which musical is it that the brooms sing 'Chim Chim Cheree' in?
#
#
#
#
# Original Question: {'question': "Who had a big 60s No 1 with Tossin' and Turnin'?"}
# Rewritten Question: Who had a massive 1960s hit with "Tossin' and Turnin'"?
#
#
#
#
# Original Question: {'question': 'Sam Phillips was owner of which legendary recording studio?'}
# Rewritten Question: {'question': 'Which legendary recording studio was owned by Sam Phillips?
#
#
#
#
# Original Question: {'question': 'Which actor played Maxwell Smart?'}
# Rewritten Question: {'question': 'Who portrayed Maxwell Smart?
#
#
#
#
# Original Question: {'question': 'On a computer keyboard which letter on the same line is between C and B?'}
# Rewritten Question: Which letter on the same line as 'C' is also located between 'C' and 'B'?
#
#
#
#
# Original Question: {'question': "Lunar 10's Lunar Excursion Module was named after which famous character?"}
# Rewritten Question: {'question': "Which famous character is the Lunar 10's Lunar Excursion Module named after?
#
#
#
#
# Original Question: {'question': 'In which decade did golfer Gary Player last win the British Open?'}
# Rewritten Question: {'question': 'When did golfer Gary Player last win the British Open, according to the given decade?
#
#
#
#
# Original Question: {'question': 'Sarah FitzGerald has been a 90s world champion in which sport?'}
# Rewritten Question: {'question': 'Which sport has Sarah FitzGerald been a 90s world champion in?
#
#
#
#
# Original Question: {'question': 'Where was the peace treaty signed that brought World War I to an end?'}
# Rewritten Question: {'question': 'Which location marked the end of World War I by signing a treaty?
#
#
#
#
# Original Question: {'question': 'Which Welsh singer was invited to sing at the White House on Millennium Eve?'}
# Rewritten Question: {'question': 'Who was the Welsh singer invited to perform at the White House on the eve of the millennium?
#
#
#
#
# Original Question: {'question': 'Which company was responsible for the oil spill in Alaska in 1989?'}
# Rewritten Question: {'question': 'Who was responsible for the oil spill in Alaska in 1989?
#
#
#
#
# Original Question: {'question': "What date is Father's Day?"}
# Rewritten Question: When is Father's Day?
#
#
#
#
# Original Question: {'question': 'In which decade of the 20th century was the FBI set up?'}
# Rewritten Question: During which decade of the 20th century was the FBI established?
#
#
#
#
# Original Question: {'question': 'In which decade of the 20th century was Dan Aykroyd born?'}
# Rewritten Question: {'question': 'When was Dan Aykroyd born, according to the 20th century?
#
#
#
#
# Original Question: {'question': 'Which American wrote The Game of Chess in 1959?'}
# Rewritten Question: Who authored The Game of Chess in 1959, an American writer?
#
#
#
#
# Original Question: {'question': 'Which leader did Hitler meet in the Brenner Pass in WWII?'}
# Rewritten Question: {'question': 'Who did Hitler encounter in the Brenner Pass during WWII?
#
#
#
#
# Original Question: {'question': 'Which company first manufactured the electric toothbrush?'}
# Rewritten Question: Who was the first company to produce the electric toothbrush?
#
#
#
#
# Original Question: {'question': 'Who lived under the pseudonym of Harriet Brown in New York form the 40s to the 90s?'}
# Rewritten Question: Who used the pseudonym Harriet Brown in New York from the 1940s to the 1990s?
#
#
#
#
# Original Question: {'question': 'Which actor bought the island of Tetiaroa?'}
# Rewritten Question: {'question': 'Who acquired the island of Tetiaroa?
#
#
#
#
# Original Question: {'question': 'Between 1952 and 1954 did the number of TV stations in the USA double, triple or quadruple?'}
# Rewritten Question: Did the number of TV stations in the USA double, triple, or quadruple between 1952 and 1954?
#
#
#
#
# Original Question: {'question': "What was Wham!'s first No 1?"}
# Rewritten Question: What was Wham!'s initial chart-topping single?
#
#
#
#
# Original Question: {'question': "Which musical featured the song You'll Never Walk Alone?"}
# Rewritten Question: Which musical featured the song "You'll Never Walk Alone"?
#
#
#
#
# Original Question: {'question': 'In which year was Bloody Sunday in Londonderry?'}
# Rewritten Question: {'question': 'When did the Bloody Sunday incident occur in Londonderry?
#
#
#
#
# Original Question: {'question': 'The first untethered space walk took place from which space craft?'}
# Rewritten Question: {'question': 'Which spacecraft did the first untethered spacewalk take place from?
#
#
#
#
# Original Question: {'question': 'What was the main color of a Storm trooper in Star Wars?'}
# Rewritten Question: What color was the primary uniform color of a Stormtrooper in the Star Wars franchise?
#
#
#
#
# Original Question: {'question': 'Richard Nixon was Vice President to which US state?'}
# Rewritten Question: {'question': 'Which US state did Richard Nixon serve as Vice President to?
#
#
#
#
# Original Question: {'question': 'Luxor international airport is in which country?'}
# Rewritten Question: {'question': 'Which country is Luxor international airport located in?
#
#
#
#
# Original Question: {'question': 'Which country did Albert Einstein move to as the Nazis rose to power?'}
# Rewritten Question: Which country did Albert Einstein relocate to as the Nazi party gained power?
#
#
#
#
# Original Question: {'question': 'In the 90s how many points have been awarded for finishing first in a Grand Prix?'}
# Rewritten Question: In the 1990s, how many points were awarded for finishing first in a Grand Prix?
#
#
#
#
# Original Question: {'question': 'Which lawyer made Raymond Burr famous?'}
# Rewritten Question: {'question': 'Who credit for Raymond Burr's fame?
#
#
#
#
# Original Question: {'question': 'Which broadcasting company did Edward J Noble found?'}
# Rewritten Question: Why did the company have to discontinue its operations?
#
#
#
#
# Original Question: {'question': 'In which decade did the Jackson 5 sign to Motown?'}
# Rewritten Question: {'question': 'When did the Jackson 5 join Motown?
#
#
#
#
# Original Question: {'question': 'How many vice presidents did Franklin D Roosevelt have?'}
# Rewritten Question: How many deputies did Franklin D Roosevelt have?
#
#
#
#
# Original Question: {'question': "In which state is Harrah's Auto Collection situated?"}
# Rewritten Question: In what state is Harrah's Auto Collection located?
#
#
#
#
# Original Question: {'question': "What was the name of Gene Autry's horse?"}
# Rewritten Question: What was the name of Gene Autry's famous horse?
#
#
#
#
# Original Question: {'question': 'Which city has a sports team of Steelers and team of Pirates?'}
# Rewritten Question: Which metropolis has a squad of Steelers and a team of Pirates?
#
#
#
#
# Original Question: {'question': 'What did Fort Dearborn, Indian Territory change its name to?'}
# Rewritten Question: {'question': 'What did Fort Dearborn, which was located in Indian Territory, change its name to?
#
#
#
#
# Original Question: {'question': 'Bill Berry retired through ill health as a drummer in which band?'}
# Rewritten Question: {'question': 'Which band did Bill Berry retire from due to ill health?
#
#
#
#
# Original Question: {'question': 'Leslie Nielsen trained in which of the armed services in WWII?'}
# Rewritten Question: {'question': 'Which military branch did Leslie Nielsen train in during WWII?

# %%
import pandas as pd
import re

# %%
import torch
import numpy as np
from nltk.util import ngrams
import pandas as pd

def calculate_ngram_accuracy(reference, generated, n=2):
    """
    Calculate N-gram accuracy between a reference and generated text.
    """
    ref_ngrams = set([' '.join(reference[i:i + n]) for i in range(len(reference) - n + 1)])
    gen_ngrams = set([' '.join(generated[i:i + n]) for i in range(len(generated) - n + 1)])
    matches = len(ref_ngrams & gen_ngrams)
    return matches / len(ref_ngrams) if len(ref_ngrams) > 0 else 0.0

def process_text(text):
    """
    Tokenize text into words.
    """
    return text.split()

# %%
import pandas as pd
import numpy as np

# Placeholder function for text processing (you can customize this as needed)
def process_text(text):
    return text.lower() if isinstance(text, str) else ""

# Placeholder function for n-gram accuracy calculation
def calculate_ngram_accuracy(text1, text2, n=2):
    """
    Calculates the N-gram accuracy between two texts.
    """
    def ngrams(text, n):
        tokens = text.split()
        return [tuple(tokens[i:i+n]) for i in range(len(tokens)-n+1)]
    
    ngrams1 = set(ngrams(text1, n))
    ngrams2 = set(ngrams(text2, n))
    
    if not ngrams1:  # Handle empty text case
        return 0.0
    return len(ngrams1.intersection(ngrams2)) / len(ngrams1)

def evaluate_atomic_metric(original_dataset, rewritten_dataset, n=2):
    """
    Evaluate the atomic metric (N-gram accuracy) and calculate decrement (∆) and percentage decrease (δ).
    """
    if len(original_dataset) != len(rewritten_dataset):
        raise ValueError("Original and rewritten datasets must have the same number of rows.")
    
    # N-gram accuracies for the rewritten dataset
    accuracies = []
    for (_, orig_row), (_, rewritten_row) in zip(original_dataset.iterrows(), rewritten_dataset.iterrows()):
        original_question = process_text(orig_row["Original Question"])
        rewritten_question = process_text(rewritten_row["Rewritten Question"])
        
        accuracy = calculate_ngram_accuracy(original_question, rewritten_question, n=n)
        accuracies.append(accuracy)
    
    M_ref = np.mean(accuracies)

    # N-gram accuracies for the original dataset against itself (optional: full similarity)
    self_accuracies = []
    for _, row in original_dataset.iterrows():
        original_question = process_text(row["Original Question"])
        accuracy = calculate_ngram_accuracy(original_question, original_question, n=n)
        self_accuracies.append(accuracy)
    
    M_ori = np.mean(self_accuracies)

    # Calculate decrement (∆) and percentage decrease (δ)
    delta = M_ori - M_ref
    delta_relative = (delta / M_ori) * 100 if M_ori != 0 else 0

    return {
        "M_ori": M_ori,
        "M_ref": M_ref,
        "Delta (∆)": delta,
        "Delta Relative (δ)": delta_relative
    }

# Example Usage
# Load the CSV files
training_dataset = pd.read_csv('output_data_question_train.csv')  # Replace with the actual file path
testing_dataset = pd.read_csv('output_data_question_test.csv')    # Replace with the actual file path

# Evaluate metrics for training data
print("Training Dataset:")
training_results = evaluate_atomic_metric(
    training_dataset[["Original Question"]], 
    training_dataset[["Rewritten Question"]],
    n=2
)
for key, value in training_results.items():
    print(f"  {key}: {value:.4f}")

# Evaluate metrics for testing data
print("\nTesting Dataset:")
testing_results = evaluate_atomic_metric(
    testing_dataset[["Original Question"]], 
    testing_dataset[["Rewritten Question"]],
    n=2
)
for key, value in testing_results.items():
    print(f"  {key}: {value:.4f}")
# Out:
# Training Dataset:
#   M_ori: 1.0000
#   M_ref: 0.3052
#   Delta (∆): 0.6948
#   Delta Relative (δ): 69.4818
#
# Testing Dataset:
#   M_ori: 1.0000
#   M_ref: 0.3031
#   Delta (∆): 0.6969
#   Delta Relative (δ): 69.6932
